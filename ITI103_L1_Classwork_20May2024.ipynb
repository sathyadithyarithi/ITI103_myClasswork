# %% [markdown]
# <a href="https://colab.research.google.com/github/sathyadithyarithi/ITI103_myClasswork/blob/main/ITI103_L1_Classwork_20May2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s = pd.Series( [1, 0, 2, -4], index=['a', 'b', 'c', 'd'] )

s
# Out:
# a    1
# b    0
# c    2
# d   -4
# dtype: int64

# %%
data = {'country': ['Japan', 'Thailand', 'Indonesia'],
	'capital': ['Tokyo', 'Bangkok', 'Jakarta'],
	'population': [126800000, 69040000, 264000000]}
df = pd.DataFrame(data, columns=['country', 'capital', 'population'])
df
# Out:
#      country  capital  population
# 0      Japan    Tokyo   126800000
# 1   Thailand  Bangkok    69040000
# 2  Indonesia  Jakarta   264000000

# %%
step_data = [3620,7891,9761,1907,4338,5373]
step_counts = pd.Series(step_data,name='steps')
print(step_counts)
# Out:
# 0    3620
# 1    7891
# 2    9761
# 3    1907
# 4    4338
# 5    5373
# Name: steps, dtype: int64

# %%
step_counts.index = pd.date_range('20150329',periods=6)
print(step_counts)
# Out:
# 2015-03-29    3620
# 2015-03-30    7891
# 2015-03-31    9761
# 2015-04-01    1907
# 2015-04-02    4338
# 2015-04-03    5373
# Freq: D, Name: steps, dtype: int64

# %%
# Just like a dictionary
print(step_counts['2015-04-01'])
# Or by index position--like an array
print(step_counts[3])

# Select all of April
print(step_counts['2015-04'])
# Out:
# 1907
# 1907
# 2015-04-01    1907
# 2015-04-02    4338
# 2015-04-03    5373
# Freq: D, Name: steps, dtype: int64

# %%
import numpy as np

# View the data type
print(step_counts.dtypes)
# Convert to a float
step_counts=step_counts.astype(np.float64)
# View the data type
print("step count",step_counts.dtypes)
# Out:
# float64
# step count float64

# %%
# Create invalid data
step_counts[1:3] = np.NaN

# Now fill it in with zeros
step_counts = step_counts.fillna(0.)
# equivalently,
# step_counts.fillna(0., inplace=True)

print(step_counts[1:3])
# Out:
# 2015-03-30    0.0
# 2015-03-31    0.0
# Freq: D, Name: steps, dtype: float64

# %%
# Create invalid data
step_counts[1:3] = np.NaN

# Now fill it in with zeros
step_counts = step_counts.fillna(0.)
# equivalently,
# step_counts.fillna(0., inplace=True)

print(step_counts[1:3])
# Out:
# 2015-03-30    0.0
# 2015-03-31    0.0
# Freq: D, Name: steps, dtype: float64

# %%
# Cycling distance
cycling_data = [10.7, 0, None, 2.4, 15.3, 10.9, 0, None]

# Create a tuple of data
joined_data = list(zip(step_data, cycling_data))

# The dataframe
activity_df = pd.DataFrame(joined_data)

print(activity_df)
# Out:
#       0     1
# 0  3620  10.7
# 1  7891   0.0
# 2  9761   NaN
# 3  1907   2.4
# 4  4338  15.3
# 5  5373  10.9

# %%
# Add column names to dataframe
activity_df = pd.DataFrame(
    joined_data,
index=pd.date_range('20150329', periods=6),
columns=['Walking','Cycling'])

print(activity_df)
# Out:
#             Walking  Cycling
# 2015-03-29     3620     10.7
# 2015-03-30     7891      0.0
# 2015-03-31     9761      NaN
# 2015-04-01     1907      2.4
# 2015-04-02     4338     15.3
# 2015-04-03     5373     10.9

# %%
# Select row of data by index name
print(activity_df.loc['2015-04-01'])
# Out:
# Walking    1907.0
# Cycling       2.4
# Name: 2015-04-01 00:00:00, dtype: float64

# %%
# Select row of data by integer position
print(activity_df.iloc[-3])
# Out:
# Walking    1907.0
# Cycling       2.4
# Name: 2015-04-01 00:00:00, dtype: float64

# %%
# Name of column
print(activity_df['Walking'])
# Out:
# 2015-03-29    3620
# 2015-03-30    7891
# 2015-03-31    9761
# 2015-04-01    1907
# 2015-04-02    4338
# 2015-04-03    5373
# Freq: D, Name: Walking, dtype: int64

# %%
# Object-oriented approach
print(activity_df.Walking)
# Out:
# 2015-03-29    3620
# 2015-03-30    7891
# 2015-03-31    9761
# 2015-04-01    1907
# 2015-04-02    4338
# 2015-04-03    5373
# Freq: D, Name: Walking, dtype: int64

# %%
# First column
print(activity_df.iloc[:,0])

# %%
# The location of the data file
filepath='https://raw.githubusercontent.com/nyp-sit/data/master/Iris_Data.csv'
# Import the data
data = pd.read_csv(filepath)

# Print a few rows
print(data.iloc[:5])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Create a new column that is a product
# of both measurements
data['sepal_area'] = data.sepal_length * 		    data.sepal_width

# Print a few rows and columns
print(data.iloc[:5, -3:])
# Out:
#    petal_width      species  sepal_area
# 0          0.2  Iris-setosa       17.85
# 1          0.2  Iris-setosa       14.70
# 2          0.2  Iris-setosa       15.04
# 3          0.2  Iris-setosa       14.26
# 4          0.2  Iris-setosa       18.00

# %%
# The lambda function applies what
# follows it to each row of data
data['abbrev'] = (data
                 .species
                 .apply(lambda x:             	 	 x.replace('Iris-','')))
# Note that there are other ways to
# accomplish the above

print(data.iloc[:5, -3:])
# Out:
#        species  sepal_area  abbrev
# 0  Iris-setosa       17.85  setosa
# 1  Iris-setosa       14.70  setosa
# 2  Iris-setosa       15.04  setosa
# 3  Iris-setosa       14.26  setosa
# 4  Iris-setosa       18.00  setosa

# %%
# Concatenate the first two and
# last two rows
small_data = pd.concat([data.iloc[:2],
 data.iloc[-2:]])
print(small_data.iloc[:,-3:])

# See the 'join' method for
# SQL style joining of dataframes
# Out:
#             species  sepal_area     abbrev
# 0       Iris-setosa       17.85     setosa
# 1       Iris-setosa       14.70     setosa
# 148  Iris-virginica       21.08  virginica
# 149  Iris-virginica       17.70  virginica

# %%
# Use the size method with a
# DataFrame to get count
# For a Series, use the .value_counts
# method
group_sizes = (data
              .groupby('species')
              .size())

print(group_sizes)
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
# Mean calculated on a DataFrame
# added numeic_only=True as the column has other data types
print(data.mean(numeric_only=True))
# Median calculated on a Series , added numeric_only=True
print(data.petal_length.median(numeric_only=True))
# Mode calculated on a Series
print("check Mode")   # with and without numeric_only=True
print(data.petal_length.mode())
# Out:
# sepal_length     5.843333
# sepal_width      3.054000
# petal_length     3.758667
# petal_width      1.198667
# sepal_area      17.806533
# dtype: float64
# 4.35
# check Mode
# 0    1.5
# Name: petal_length, dtype: float64

# %%
# Standard dev, variance, and SEM
print(data.petal_length.std(),
      data.petal_length.var(),
      data.petal_length.sem())
# As well as quantiles
print(data.quantile(0))
# Out:
# 1.7644204199522626 3.113179418344519 0.1440643240210085
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-6cc3ee75f754> in <cell line: 6>()
#       4       data.petal_length.sem())
#       5 # As well as quantiles
# ----> 6 print(data.quantile())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   10880             # ExtensionArray, ndarray[Any, Any]], Index, Series], Sequence[float]]";
#   10881             # expected "float"
# > 10882             res_df = self.quantile(  # type: ignore[call-overload]
#   10883                 [q],
#   10884                 axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in quantile(self, q, axis, numeric_only, interpolation, method)
#   10925             )
#   10926         if method == "single":
# ...

# %%
print(data.describe())
# Out:
#        sepal_length  sepal_width  petal_length  petal_width  sepal_area
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.054000      3.758667     1.198667   17.806533
# std        0.828066     0.433594      1.764420     0.763161    3.368693
# min        4.300000     2.000000      1.000000     0.100000   10.000000
# 25%        5.100000     2.800000      1.600000     0.300000   15.645000
# 50%        5.800000     3.000000      4.350000     1.300000   17.660000
# 75%        6.400000     3.300000      5.100000     1.800000   20.325000
# max        7.900000     4.400000      6.900000     2.500000   30.020000

# %%
# Sample 5 rows without replacement
sample = (data
.sample(n=5,
replace=False,
random_state=42))
print(sample.iloc[:,-3:])
# Out:
#              species  sepal_area      abbrev
# 73   Iris-versicolor       17.08  versicolor
# 18       Iris-setosa       21.66      setosa
# 118   Iris-virginica       20.02   virginica
# 78   Iris-versicolor       17.40  versicolor
# 76   Iris-versicolor       19.04  versicolor

# %%
# Sample 5 rows without replacement
sample = (data
   .sample(n=5,
 replace=False,
 random_state=42))    # make sure you use the entire code usues 42, if you are vusing 50, use 50 in the entire code
print(sample.iloc[:,-3:])
# Out:
#              species  sepal_area      abbrev
# 73   Iris-versicolor       17.08  versicolor
# 18       Iris-setosa       21.66      setosa
# 118   Iris-virginica       20.02   virginica
# 78   Iris-versicolor       17.40  versicolor
# 76   Iris-versicolor       19.04  versicolor

# %% [markdown]
# #MATHPLOT

# %%
import matplotlib.pyplot as plt
plt.plot(data.sepal_length, data.sepal_width,ls ='', marker='o')

# %%
plt.plot(data.sepal_length,data.sepal_width,
	 ls ='', marker='o',
	 label='sepal')

plt.plot(data.petal_length,
	 data.petal_width,
    ls ='', marker='o',
	 label='petal')

# %%
plt.hist(data.sepal_length, bins=25)
# Out:
# (array([ 4.,  1.,  6.,  5., 16.,  9.,  5.,  6.,  7., 14.,  7.,  9.,  6.,
#         13.,  7.,  7.,  8.,  3.,  5.,  1.,  4.,  1.,  1.,  4.,  1.]),
#  array([4.3  , 4.444, 4.588, 4.732, 4.876, 5.02 , 5.164, 5.308, 5.452,
#         5.596, 5.74 , 5.884, 6.028, 6.172, 6.316, 6.46 , 6.604, 6.748,
#         6.892, 7.036, 7.18 , 7.324, 7.468, 7.612, 7.756, 7.9  ]),
#  <BarContainer object of 25 artists>)

# %%
fig, ax = plt.subplots()

ax.barh(np.arange(10),
  data.sepal_width.iloc[:10])
# Set position of ticks and tick labels
ax.set_yticks(np.arange(0.4,10.4,1.0))
ax.set_yticklabels(np.arange(1,11))
ax.set(xlabel='xlabel', ylabel='ylabel',
       title='Title')
# Out:
# [Text(0.5, 0, 'xlabel'), Text(0, 0.5, 'ylabel'), Text(0.5, 1.0, 'Title')]

# %%
(data
 .groupby('species')
 .mean()
 .plot(color=['red','blue',
  	     'black','green'],
       fontsize=10.0, figsize=(4,4)))
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# ...

# %%
import seaborn as sns
sns.jointplot(x='sepal_length',
	      y='sepal_width',
	      data=data, size=4)

# %%
sns.pairplot(data, hue='species',size=3)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
